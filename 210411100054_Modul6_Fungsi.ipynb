# %% [markdown]
# **NAMA : SITI NUR AINI**
#
# **NIM : 210411100054**
#
# **MODUL 6 - FUNGSI**

# %% [markdown]
# # **1 Fungsi**
#
# ---
# Tulis ringkasan atau penjelasan hal-hal berikut, dengan kata-kata kalian sendiri :
#
#
# ---

# %% [markdown]
# ##### **1. Sebutkan alasan kenapa kita harus menggunakan Fungsi (Function), jika perlu tambahkan contoh**

# %% [markdown]
# **Alasan menggunakan fungsi (function)**
#
# *   Dapat dipanggil kembali (berulang kali), dimanapun fungsi tersebut dibutuhkan
#
# *   Code manjadi lebih ringkas, dan jumlah baris menjadi lebih sedikit
# *   Code manjadi lebih mudah untuk dibaca : edit, update, dan cek error
#
# **contoh**

# %%
def salam():
  print('hallo aini, selamat belajar function python')

salam()
# Out:
# hallo aini, selamat belajar function python

# %% [markdown]
# ##### **2. Sebutkan Jenis Fungsi dan perbedaannya, syntax umum dari fungsi tersebut, berikana contoh**

# %% [markdown]
# **Jenis Fungsi**
#
#
# *   tanpa parameter, tanpa return value
#
# *   dengan parameter atau argumen
# *   dengan parameter atau argumen dan dengan return vallue

# %%
# syntax umum function
def <nama_fungsi>(parameters1, parameter2, ...):
  statements
  return value1, value2, ...

# %%
# contoh fungsi tanpa parameter, tanpa return value
def salam():
  print('selamat mengerjakan aini')

salam()
# Out:
# selamat mengerjakan aini

# %%
# contoh fungsi dengan parameter
def salam(selamat):
  print(selamat)

salam('selamat pagi')
salam('selamat siang')
salam('selamat sore')
salam('selamat malam')
# Out:
# selamat pagi
# selamat siang
# selamat sore
# selamat malam

# %%
# contoh function dengan parameter dan dengan return value
def sisi(panjang, lebar):
  luas = panjang * lebar
  return luas

print('luas persegi panjang =', sisi(7, 9))
print('luas persegi panjang =', sisi(5, 2))
print('luas persegi panjang =', sisi(100, 43))
# Out:
# luas persegi panjang = 63
# luas persegi panjang = 10
# luas persegi panjang = 4300

# %% [markdown]
# # **2 Implementasi**

# %% [markdown]
# #### **2.1 Cek List**
# Buatlah Fungsi dan code untuk memanggil fungsi dengan menggunakan Python, antara lain :
#
# *   Fungsi **createList** untuk membentuk suatu list dengan parameter atau argumen berupa ukuran list
# *   Fungsi **isPrime** untuk menentukan apakah suatu bilangan adalah bilangan prima, dengan argumen
# adalah bilangan yang akan dicek
#
# *   Fungsi **createListPrime** untuk membuat suatu list yang berisi bilangan prima, dengan ketentuan :
#
#     – argumen atau paramater adalah list dimana di setiap anggotanya akan dicek termasuk bilangan prima ataukah tidak
#
#     – gunakan fungsi isPrime yang sudah dibuat, untuk cek apakah suatu bilangan adalah bilangan prima
#
#     – anggota-anggota list yang dihasilkan dari fungsi ini, tidak boleh sama [Hint: gunakan in]
#
# Contoh output yang dihasilkan dapat dilihat pada Gambar 1.
#
#
# ![Screenshot (713).png](data:image/png;base64,...)

# %%
# (a) Size List utama = 10
hasil = []
list_prima = []

def createList(a):
    for i in range(0, a):
        ukuran = int(input('masukkan data ke- ' + str(i) + ' : '))
        hasil.append(ukuran)
    return hasil

def isPrime(a):
    count = 0
    for y in range(1, a + 1):
        if a % y == 0:
            count += 1
    if count == 2:
        for i in list_prima:
            if a == i:
                break
        else:
            list_prima.append(a)

def createListPrima(data):
    for i in data:
        isPrime(i)
    return list_prima

data = createList(10)
print('data list = ', data)
prima = createListPrima(data)
print('data prima = ', prima)
# Out:
# masukkan data ke- 0 : 7
# masukkan data ke- 1 : 2
# masukkan data ke- 2 : 4
# masukkan data ke- 3 : 6
# masukkan data ke- 4 : 5
# masukkan data ke- 5 : 2
# masukkan data ke- 6 : 9
# masukkan data ke- 7 : 5
# masukkan data ke- 8 : 8
# masukkan data ke- 9 : 1
# data list =  [7, 2, 4, 6, 5, 2, 9, 5, 8, 1]
# data prima =  [7, 2, 5]

# %%
# (b) Size List utama = 15
hasil = []
list_prima = []

def createList(a):
    for i in range(0, a):
        ukuran = int(input('masukkan data ke- ' + str(i) + ' : '))
        hasil.append(ukuran)
    return hasil

def isPrime(a):
    count = 0
    for y in range(1, a + 1):
        if a % y == 0:
            count += 1
    if count == 2:
        for i in list_prima:
            if a == i:
                break
        else:
            list_prima.append(a)

def createListPrima(data):
    for i in data:
        isPrime(i)
    return list_prima

data = createList(15)
print('data list = ', data)
prima = createListPrima(data)
print('data prima = ', prima)
# Out:
# masukkan data ke- 0 : 8
# masukkan data ke- 1 : 1
# masukkan data ke- 2 : 2
# masukkan data ke- 3 : 6
# masukkan data ke- 4 : 3
# masukkan data ke- 5 : 5
# masukkan data ke- 6 : 2
# masukkan data ke- 7 : 9
# masukkan data ke- 8 : 0
# masukkan data ke- 9 : 11
# masukkan data ke- 10 : 3
# masukkan data ke- 11 : 2
# masukkan data ke- 12 : 7
# masukkan data ke- 13 : 9
# masukkan data ke- 14 : 1
# data list =  [8, 1, 2, 6, 3, 5, 2, 9, 0, 11, 3, 2, 7, 9, 1]
# data prima =  [2, 3, 5, 11, 7]

# %% [markdown]
# #### **2.2 Operasi List**
# Buatlah Fungsi dan code untuk memanggil fungsi dengan menggunakan Python, antara lain :
#
# *    Fungsi **createList** untuk membentuk suatu list dengan parameter atau argumen berupa ukuran list
#
# *    Fungsi **avgList** untuk menghitung rata-rata suatu list, dengan argumen adalah list
#
# *    Fungsi **addList** untuk menjumlahkan dua buah list yang memiliki ukuran yang sama
#
# Contoh output yang dihasilkan dapat dilihat pada Gambar 2.
#
# ![Screenshot (714).png](data:image/png;base64,...)

# %%
# (a) Ukuran List Tidak Sama
def createList(a):
    ukuran = []
    for i in range(a):
        b = int(input('Masukkan data Ke - ' + str(i) + ' : '))
        ukuran.append(b)
    return ukuran

def avgList(list):
    x = len(list)
    y = 0
    for i in list:
        y += i
    rata2 = y / x
    return rata2

def addList (a, b):
    tambah1 = len(a)
    tambah2 = len(b)
    hasil = []
    if tambah1 == tambah2:
        for i in range(tambah1):
            total = a[i] + b[i]
            hasil.append(total)
        return hasil
    else :
      return ("Ukuran List Tidak Sama")

data1 = createList(4)
print('data - 1 = ', data1, '; rata-rata list = ', avgList(data1))
data2 = createList(5)
print('data - 2 = ', data2, '; rata-rata list = ', avgList(data2))
hasil = addList(data1, data2)
print(data1, '+', data2, '=', hasil)
# Out:
# Masukkan data Ke - 0 : 4
# Masukkan data Ke - 1 : 1
# Masukkan data Ke - 2 : 2
# Masukkan data Ke - 3 : 4
# data - 1 =  [4, 1, 2, 4] ; rata-rata list =  2.75
# Masukkan data Ke - 0 : 4
# Masukkan data Ke - 1 : 7
# Masukkan data Ke - 2 : 5
# Masukkan data Ke - 3 : 3
# Masukkan data Ke - 4 : 8
# data - 2 =  [4, 7, 5, 3, 8] ; rata-rata list =  5.4
# [4, 1, 2, 4] + [4, 7, 5, 3, 8] = Ukuran List Tidak Sama

# %%
# (b) Ukuran List Sama
def createList(a):
    ukuran = []
    for i in range(a):
        b = int(input('Masukkan data Ke - ' + str(i) + ' : '))
        ukuran.append(b)
    return ukuran

def avgList(list):
    x = len(list)
    y = 0
    for i in list:
        y += i
    rata2 = y / x
    return rata2

def addList (a, b):
    tambah1 = len(a)
    tambah2 = len(b)
    hasil = []
    if tambah1 == tambah2:
        for i in range(tambah1):
            total = a[i] + b[i]
            hasil.append(total)
        return hasil
    else :
      return ("Ukuran List Tidak Sama")

data1 = createList(6)
print('data - 1 = ', data1, '; rata-rata list = ', avgList(data1))
data2 = createList(6)
print('data - 2 = ', data2, '; rata-rata list = ', avgList(data2))
hasil = addList(data1, data2)
print(data1, '+', data2, '=', hasil)
# Out:
# Masukkan data Ke - 0 : 4
# Masukkan data Ke - 1 : 2
# Masukkan data Ke - 2 : 4
# Masukkan data Ke - 3 : 7
# Masukkan data Ke - 4 : 8
# Masukkan data Ke - 5 : 2
# data - 1 =  [4, 2, 4, 7, 8, 2] ; rata-rata list =  4.5
# Masukkan data Ke - 0 : 1
# Masukkan data Ke - 1 : 4
# Masukkan data Ke - 2 : 10
# Masukkan data Ke - 3 : 4
# Masukkan data Ke - 4 : 5
# Masukkan data Ke - 5 : 6
# data - 2 =  [1, 4, 10, 4, 5, 6] ; rata-rata list =  5.0
# [4, 2, 4, 7, 8, 2] + [1, 4, 10, 4, 5, 6] = [5, 6, 14, 11, 13, 8]

# %%
# (c) Ukuran List sama dan dilakukan Operasi Penjumlahan Kembali
def createList(a):
    ukuran = []
    for i in range(a):
        b = int(input('Masukkan data Ke - ' + str(i) + ' : '))
        ukuran.append(b)
    return ukuran

def avgList(list):
    x = len(list)
    y = 0
    for i in list:
        y += i
    rata2 = y / x
    return rata2

def addList (a, b):
    tambah1 = len(a)
    tambah2 = len(b)
    hasil = []
    if tambah1 == tambah2:
        for i in range(tambah1):
            total = a[i] + b[i]
            hasil.append(total)
        return hasil
    else :
      return ("Ukuran List Tidak Sama")

data1 = createList(3)
print('data - 1 = ', data1, '; rata-rata list = ', avgList(data1))
data2 = createList(3)
print('data - 2 = ', data2, '; rata-rata list = ', avgList(data2))
hasil = addList(data1, data2)
hasil2 = addList(hasil, hasil)
print(data1, '+', data2, '=', hasil)
print(hasil, '+', hasil, '=', hasil2)
# Out:
# Masukkan data Ke - 0 : 2
# Masukkan data Ke - 1 : 3
# Masukkan data Ke - 2 : 4
# data - 1 =  [2, 3, 4] ; rata-rata list =  3.0
# Masukkan data Ke - 0 : 2
# Masukkan data Ke - 1 : 6
# Masukkan data Ke - 2 : 7
# data - 2 =  [2, 6, 7] ; rata-rata list =  5.0
# [2, 3, 4] + [2, 6, 7] = [4, 9, 11]
# [4, 9, 11] + [4, 9, 11] = [8, 18, 22]

# %% [markdown]
# #### **2.3 Flowchart Function**
# Buatlah flowchart dari fungsi dan main code yang sudah dikerjakan pada nomor sebelumnya (Operasi List).
# ![mod 6 - Main.png](data:image/png;base64,...)
#
# ![mod 6 - createList.png](data:image/png;base64,...)
#
# ![mod 6 - avgList.png](data:image/png;base64,...)
#
# ![mod 6 - addList.png](data:image/png;base64,...)
